# %% [markdown]
# # Gen3 Butler Basics

# %% [markdown]
# ## Environment setup
#
# This tutorial runs against a built copy of the [ci_hsc_gen3](https://github.com/lsst/ci_hsc_gen3) package.  As of this writing, a copy can be found at `/project/jbosch/gen3/bootcamp/ci_hsc_gen3` on `lsst-dev` or the LSP.  The notebook was originally written against stack release `w_2019_45`, but probably works with many others around the same time; most of the interfaces demonstrated here are fairly stable, and can be run with a "small" JupyterLab instance in the LSP.

# %%
import os
#REPO_ROOT = "/project/jbosch/gen3/bootcamp/ci_hsc_gen3/DATA"
REPO_ROOT = "/global/cscratch1/sd/desc/DC2/gen3/Run2.2i-gen3"

# %% [markdown]
# ## Data Repositories and Collections

# %% [markdown]
# As in Gen2, you initialize a `Butler` by pointing at a data repository, which is usually represented by a directory with a `butler.yaml` file in it.
#
# Unlike Gen2, that's not enough; you need to pass a `collection` name, too:

# %%
from lsst.daf.butler import Butler
butler = Butler(REPO_ROOT, collections="desc/demo")

# %% [markdown]
# That's because a Gen3 data repository is actually more like a set of related Gen2 data repositories (_e.g._ `/datasets/hsc/repo` and all of the data repositories that (recursively) consider it a parent.  A Gen3 `collection` is like a specific Gen2 data repository, and while some collections may also be associated with subdirectories, that's not true in general.
#
# The `shared/ci_hsc_output` collection is the one that holds the results of building ci_hsc_gen3 (and hence running a bunch of `PipelineTask`.  There are lots of other collections here:

# %%
butler.registry.queryCollections()
# Out:
# <generator object Registry.queryCollections at 0x2aaad0f825d0>

# %% [markdown]
# There's clearly the beginning of convention here for how to name collections, but it hasn't been worked out in detail.  From the perspective of the code, they're just strings, and the slashes don't mean anything.

# %% [markdown]
# ## Registry and Datastore

# %% [markdown]
# The last call was actually on `butler.registry`, not just `butler`, and that'll be a relatively common occurrence in Gen3, because a `Butler` is really just a convenience wrapper that combines three things:
#
# * a `Registry` instance that manages metadata and relationships between datasets via a SQL database (a `gen3.sqlite3` file in the repo root, in this case);
# * a `Datastore` instance that manages the datasets themselves (files subdirectories of the repo root, in this case);
# * the name of the `collection`.
#
# You'll frequently use `butler.registry` to perform operations that don't need anything from the `Datastore`.
#
# A `butler.datastore` attribute exists as well, but it's much less likely that you'll need to use it directly (I can't think of a reason).
#
# Neither the `Registry` nor the `Datastore` know about the `collection` you passed when constructing the `Butler`, so when using them directly you many need to pass `butler.collection` to them.

# %% [markdown]
# ## How to spell `get`

# %% [markdown]
# The most common thing you'll do with a `Butler` is call `get` (`PipelineTasks` call `put` just about as often, but usually the author of a concrete `PipelineTask` won't actually write any `get` and `put` calls).  In it's simplest form, that looks something like this:

# %%
#dataId = {"skymap": "discrete/ci_hsc", "tract": 3078, "patch": 69, "abstract_filter": "r"}
#dataId = {"skymap": "skymaps/imsim", "tract": 3078, "patch": 26, "abstract_filter": "z"}
dataId = {"skymap": "imsim_skymap", "tract": 3078, "patch": 26, "abstract_filter": "z"}

coadd = butler.get("deepCoadd", dataId=dataId)

# %% [markdown]
# There's a lot to unpack here, but let's start by making it clear that you can write this a few different ways, and they're all equivalent (and most of them are identical to Gen2, aside from what's in the data ID):

# %%
# Pass data ID as a positional argument:
coadd = butler.get("deepCoadd", dataId)

# %%
# Pass data ID as multiple keyword arguments:
coadd = butler.get("deepCoadd", skymap="imsim_skymap", tract=3078, patch=26, abstract_filter="z")

# %%
# Do both.  Keyword arguments override the data ID dict (considered a feature, though it may be suprising).
coadd = butler.get("deepCoadd", dataId, patch=26, abstract_filter="z")

# %% [markdown]
# ### DatasetTypes
#
# The first argument can also be a `DatasetType` object instead of the string that refers to one.  A `DatasetType` instance knows the data ID keys needed to identify it (we call those "dimensions") and its StorageClass, which you can think of as a mapping to the Python type you'll get back:

# %%
deepCoaddType = butler.registry.getDatasetType("deepCoadd")
print(deepCoaddType)
# Out:
# DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF)

# %% [markdown]
# In the Gen2 butler, all dataset types had to be pre-declared in an obs_ package.  In Gen3, they're added to the data repository as needed by the `PipelineTasks` that create them, so if you want to know what dataset types exist, you'll need to ask the registry (someday we'll hopefully find some way to put a snapshot of a "typical" registry's dataset types in the online documentation):

# %%
# butler.registry.getAllDatasetTypes()  Method rename HMK?

# %% [markdown]
# Note that many of those `DatasetTypes` are components of some other `DatasetType`, like `deepCoadd.psf`.  You can `get` components just as you would their parents, and usually that'll be much more efficient if the component is a small piece of the whole:

# %%
inputs = butler.get("deepCoadd.coaddInputs", dataId)
print(inputs.visits)
# Out:
#   id   bbox_min_x bbox_min_y bbox_max_x ... goodpix        weight       filter
#           pix        pix        pix     ...
# ------ ---------- ---------- ---------- ... -------- ------------------ ------
#  13289      19900      11900      24099 ...  6199167 0.6635962142150572      z
#  32683      19900      11900      24099 ... 11099088 0.7962166507011508      z
# 209058      19900      11900      24099 ... 16016002 0.5307254982981001      z
# 209066      19900      11900      24099 ... 16078479 0.5365676180201323      z
# 209091      19900      11900      24099 ... 16066550 0.5376226732711255      z
# 237907      19900      11900      24099 ...  9232702  1.044202855104819      z
# 240855      19900      11900      24099 ... 16132106 1.2021152736290244      z
# 303558      19900      11900      24099 ... 15944329 0.8779514976477992      z
# 426663      19900      11900      24099 ... 16211996 0.8029725996590692      z
# 443964      19900      11900      24099 ... 16077353  0.538738859419045      z

# %% [markdown]
# Anyhow, as promised, you can use that `DatasetType` instance in `get`:

# %%
coadd = butler.get(deepCoaddType, skymap="imsim_skymap", tract=3078, patch=26, abstract_filter="z")

# %% [markdown]
# ### DatasetRefs
#
# The Gen3 Butler makes use of the combination of a `DatasetType` and a data ID frequently enough that there is a special object for that, `DatasetRef`:

# %%
from lsst.daf.butler import DatasetRef
ref = DatasetRef(deepCoaddType, {"skymap": "imsim_skymap", "tract": 3078, "patch": 26, "abstract_filter": "z"})
print(ref)
# Out:
# deepCoadd@{abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 26}

# %% [markdown]
# You can pass a `DatasetRef` as the _only_ argument to `get`:

# %%
coadd = butler.get(ref)

# %% [markdown]
# If you're familiar with Gen2, you might have noticed that a Gen2 **DataRef** is _completely_ different from a Gen3 **DatasetRef**, and if you care about this, please chime in on [DM-21448](https://jira.lsstcorp.org/browse/DM-21448) where (among other things) I'm considering renaming it.  Everybody else: maybe don't get too attached to this name yet.

# %% [markdown]
# ### Parameters

# %% [markdown]
# Component datasets are used to get predefined, differently-typed pieces of a composite dataset.  For some dataset types it's desirable to get same-typed, parameterized subsets, and that's what the `parameters` keyword argument to `get` is for.  The classic case (and the only one supported right now) is a subimage:

# %%
from lsst.geom import Box2I, Point2I
# HMK Not sure what a good box size for DESC Run2.2i would be
#bbox = Box2I(Point2I(20000, 16000), Point2I(20200, 18000))
#parameters = {"bbox": bbox}
#subcoadd = butler.get("deepCoadd", dataId, parameters=parameters)

# %%
import numpy as np
# assert np.all(subcoadd.image.array == coadd[bbox].image.array)  HMK commenting out for now

# %% [markdown]
# Unlike Gen2,
#
# - The dataset type name is the same (still just `deepCoadd`, not `deepCoadd_sub`, as it was in Gen2).
#
# - You pass all parameters as a single dict as the `parameters` kwarg, rather than as separate kwargs that could get confused with the data ID.]
#
# Any of the alternate spellings of `get` shown above can be used with parameters, including the `DatasetRef` one - the parameters go in the call to `get`, not inside the `DatasetRef`:

# %%
# subcoadd = butler.get(ref, parameters=parameters) HMK commenting out for now

# %% [markdown]
# ## Querying for Datasets
#
# One of the most important new features of the Gen3 Butler is much more complete support for querying datasets.  That all goes through the `queryDatasets` method.  A typical query might look something like this:

# %%
list(butler.registry.queryDatasets("deepCoadd", collections=["desc/demo"]))
# Out:
# [DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 2}, id=149652, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 8}, id=149653, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 1}, id=149654, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 3}, id=149659, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 10}, id=149664, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 33}, id=149667, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 32}, id=149668, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 26}, id=149669, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 24}, id=149676, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 11}, id=149677, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 27}, id=149678, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 18}, id=149682, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 15}, id=149686, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 48}, id=149688, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 17}, id=149689, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 4}, id=149691, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 20}, id=149692, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 12}, id=149703, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 22}, id=149706, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 16}, id=149708, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 5}, id=149712, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 13}, id=149715, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 19}, id=149718, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 41}, id=149721, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 34}, id=149724, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 47}, id=149725, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 6}, id=149730, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 31}, id=149733, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 0}, id=149734, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 7}, id=149735, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 14}, id=149738, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 42}, id=149745, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 40}, id=149747, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 36}, id=149749, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 29}, id=149750, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 39}, id=149757, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 38}, id=149760, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 23}, id=149763, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 46}, id=149764, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 28}, id=149765, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 43}, id=149772, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 44}, id=149775, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 45}, id=149778, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 30}, id=149779, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 35}, id=149784, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 0}, id=149787, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 1}, id=149790, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 2}, id=149793, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 4}, id=149796, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 11}, id=149797, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 3}, id=149802, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 5}, id=149805, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 10}, id=149808, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 12}, id=149811, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 30}, id=149814, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 23}, id=149817, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 24}, id=149819, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 35}, id=149821, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 42}, id=149822, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 36}, id=149829, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 43}, id=149830, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 28}, id=149835, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 31}, id=149838, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 26}, id=149839, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 33}, id=149842, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 21}, id=149847, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 6}, id=149850, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 14}, id=149853, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 39}, id=149854, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 32}, id=149859, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 18}, id=149862, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 29}, id=149865, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 22}, id=149868, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 17}, id=149871, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 16}, id=149874, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 8}, id=149877, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 7}, id=149878, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch: 13}, id=149883, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: g, skymap: imsim_skymap, tract: 3078, patch:
run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: i, skymap: imsim_skymap, tract: 3078, patch: 26}, id=150333, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 28}, id=150336, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 35}, id=150339, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 29}, id=150340, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 36}, id=150345, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 21}, id=150348, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 41}, id=150351, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 48}, id=150354, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 37}, id=150357, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 43}, id=150360, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 44}, id=150363, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 47}, id=150366, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 45}, id=150369, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 10}, id=150372, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 17}, id=150375, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 12}, id=150378, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 11}, id=150379, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 19}, id=150384, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: i, skymap: imsim_skymap, tract: 3078, patch: 47}, id=150387, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 39}, id=150390, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 46}, id=150393, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 23}, id=150396, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 38}, id=150399, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 30}, id=150402, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 31}, id=150405, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 4}, id=150408, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 2}, id=150411, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 8}, id=150414, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 9}, id=150417, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 1}, id=150420, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 34}, id=150423, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 33}, id=150426, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 5}, id=150429, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: u, skymap: imsim_skymap, tract: 3078, patch: 6}, id=150432, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 32}, id=150433, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: r, skymap: imsim_skymap, tract: 3078, patch: 25}, id=150437, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: r, skymap: imsim_skymap, tract: 3078, patch: 8}, id=150441, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: u, skymap: imsim_skymap, tract: 3078, patch: 19}, id=150444, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 25}, id=150447, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 18}, id=150448, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: i, skymap: imsim_skymap, tract: 3078, patch: 14}, id=150453, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: i, skymap: imsim_skymap, tract: 3078, patch: 22}, id=150456, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: i, skymap: imsim_skymap, tract: 3078, patch: 16}, id=150459, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 40}, id=150462, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 0}, id=150465, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 7}, id=150468, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 42}, id=150471, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 24}, id=150474, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 6}, id=150477, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 14}, id=150480, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 15}, id=150483, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 16}, id=150484, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 25}, id=150485, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 26}, id=150492, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: r, skymap: imsim_skymap, tract: 3078, patch: 9}, id=150495, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: u, skymap: imsim_skymap, tract: 3078, patch: 26}, id=150496, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: i, skymap: imsim_skymap, tract: 3078, patch: 36}, id=150501, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: u, skymap: imsim_skymap, tract: 3078, patch: 43}, id=150504, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 13}, id=150507, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: r, skymap: imsim_skymap, tract: 3078, patch: 21}, id=150510, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: u, skymap: imsim_skymap, tract: 3078, patch: 38}, id=150513, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 22}, id=150516, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 27}, id=150519, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 20}, id=150522, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: y, skymap: imsim_skymap, tract: 3078, patch: 3}, id=150525, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: u, skymap: imsim_skymap, tract: 3078, patch: 25}, id=150528, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: i, skymap: imsim_skymap, tract: 3078, patch: 1}, id=150531, run='desc/demo/20200719T07h45m18s')]

# %% [markdown]
# We've wrapped the call in `list` because `queryDatasets` returns a single-pass iterator, not a container.  **It's also not guaranteed to return unique results**, because it might be much more expensive to do some kinds of deduplication (especially for complex queries) in the database.  We'll work on improving this in the future; right now there is a `deduplicate` option but it only deals with some kinds of duplication, and unfortunately `DatasetRef` isn't yet hashable so you can't just drop the results into a `set`.

# %% [markdown]
# You can also pass a single data ID, either as a single argument or (as with `get`) a number of keyword arguments:

# %%
list(butler.registry.queryDatasets("deepCoadd", collections=["desc/demo"],
                                   dataId={"abstract_filter": "z"}, deduplicate=True))
# Out:
# [DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 2}, id=149652, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 8}, id=149653, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 1}, id=149654, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 3}, id=149659, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 10}, id=149664, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 33}, id=149667, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 32}, id=149668, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 26}, id=149669, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 24}, id=149676, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 11}, id=149677, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 27}, id=149678, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 18}, id=149682, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 15}, id=149686, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 48}, id=149688, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 17}, id=149689, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 4}, id=149691, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 20}, id=149692, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 12}, id=149703, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 22}, id=149706, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 16}, id=149708, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 5}, id=149712, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 13}, id=149715, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 19}, id=149718, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 41}, id=149721, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 34}, id=149724, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 47}, id=149725, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 6}, id=149730, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 31}, id=149733, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 0}, id=149734, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 7}, id=149735, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 14}, id=149738, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 42}, id=149745, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 40}, id=149747, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 36}, id=149749, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 29}, id=149750, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 39}, id=149757, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 38}, id=149760, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 23}, id=149763, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 46}, id=149764, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 28}, id=149765, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 43}, id=149772, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 44}, id=149775, run='desc/demo/20200719T07h45m18s'),
#  DatasetRef(DatasetType(deepCoadd, {abstract_filter, skymap, tract, patch}, ExposureF), {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch:
run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 35, exposure: 189283}, id=1280, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 31, exposure: 189283}, id=1259, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 18, exposure: 189283}, id=1256, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 29, exposure: 189283}, id=1237, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 30, exposure: 189283}, id=1235, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 50, exposure: 227985}, id=3902, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 36, exposure: 227985}, id=3901, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 33, exposure: 227985}, id=3894, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 34, exposure: 227985}, id=3891, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 41, exposure: 227985}, id=3880, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 18, exposure: 227985}, id=3868, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 30, exposure: 227985}, id=3864, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 43, exposure: 227985}, id=3860, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 29, exposure: 227985}, id=3859, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 19, exposure: 227985}, id=3855, run='LSST-ImSim/raw/all'),
#  DatasetRef(DatasetType(raw, {abstract_filter, instrument, detector, physical_filter, exposure}, Exposure), {instrument: LSST-ImSim, detector: 45, exposure: 227985}, id=3851, run='LSST-ImSim/raw/all'),
#  ...]

# %% [markdown]
# ## Data IDs and Dimensions

# %% [markdown]
# Perhaps the biggest differences in `get` between Gen2 and Gen3 are in the data ID.  Here's the Gen3 data ID again, along with its Gen2 counterpart:

# %%
dataId_gen2 = {"tract": 3078, "patch": "5,4", "filter": "z"}
print(f"Gen3: {dataId}")
print(f"Gen2: {dataId_gen2}")
# Out:
# Gen3: {'skymap': 'imsim_skymap', 'tract': 3078, 'patch': 26, 'abstract_filter': 'z'}
# Gen2: {'tract': 3078, 'patch': '5,4', 'filter': 'z'}

# %% [markdown]
# Exactly one key-value pair is the same: `tract=0`.

# %% [markdown]
# One key-value pair has clearly has the same intent, but has both a different key and a different value: `abstract_filter="r"`.  Gen3 distinguishes between "physical" filters, which are associated with a particular piece of glass on a particular instrument (these still have names like "HSC-R"), and "abstract" filters, which are named groups of similar filters (with names like "r").  The coadd dataset types are all defined in terms of `abstract_filter`.  That's not just so we can coadd data from multiple instruments together (this is just one of several steps we'd need to enable that) - it also helps with cameras like HSC that have two versions of the same filter (i.e. "HSC-R" and "HSC-R2" are both `physical_filters`) that we want to be able to combine.
#
# Right now, each `physical_filter` corresponds to exactly one `abstract_filter` (it's many-to-one).  We know that reality is more complex than that (many-to-many), and we expect to generalize this in the future.  We're thinking about renaming `abstract_filter` to just `filter` along the way.

# %% [markdown]
# The `skymap` key is a totally new one.  In Gen3, all data IDs that involve `tract` also need to involve a `skymap` key that indicates which `skymap` defines that tract.  New skymaps can be added to a `Registry` by calling [BaseSkyMap.register](https://pipelines.lsst.io/v/weekly/py-api/lsst.skymap.BaseSkyMap.html#lsst.skymap.BaseSkyMap.register) or running the [makeGen3SkyMap.py](https://github.com/lsst/pipe_tasks/blob/master/bin.src/makeGen3Skymap.py) command-line tool (which also writes a `deepCoadd_skyMap` dataset, which we usually want).  A skymap must be added to the `Registry` before we can run any `PipelineTask` or `put` any dataset that uses it.

# %% [markdown]
# The `patch` key is present in both the Gen2 and Gen3 data IDs, but with a different value.  That's because (as per [RFC-365](https://jira.lsstcorp.org/browse/RFC-365)) `patch` identifiers in Gen3 are single integers that encode both the `x` and `y` indices.  We'll show later how to convert between these.

# %% [markdown]
# ### DataCoordinate and Dimension instances
#
# While you can still pass simple dictionaries as arguments to `Butler` and `Registry` APIs that expect data IDs, the objects we get back from the butler are always instances of `DataCoordinate`.  In fact, the data ID associated with a `DatasetRef` is a `DataCoordinate` as well:

# %%
ref.dataId
# Out:
# {abstract_filter: 'z', skymap: 'imsim_skymap', tract: 3078, patch: 26}

# %% [markdown]
# `DataCoordinate` instances are also dict-like objects, and they can be passed anywhere a dictionary-like data ID can be passed; many _internal_ `daf_butler` APIs require them.  They even look like vanilla dicts if you print them with `__str__` (`__repr__` is what's invoked above):

# %%
print(ref.dataId)
# Out:
# {abstract_filter: z, skymap: imsim_skymap, tract: 3078, patch: 26}

# %% [markdown]
# The first thing worth noting about a `DataCoordinate` is that its keys aren't actually strings; they're instances of the `Dimension` class:

# %%
ref.dataId.keys()
# Out:
# dict_keys([Dimension(abstract_filter), Dimension(skymap), Dimension(tract), Dimension(patch)])

# %% [markdown]
# `Dimension` instances are comparable to the strings that identify them, but they're much more than labels.  Using dimensions to identify datasets is a core concept for the Gen3 butler, and you can find a lot more information on it in the [API documentation](https://pipelines.lsst.io/v/weekly/modules/lsst.daf.butler/dimensions.html).  We'll cover the basics here.
#
# Most - but not all - dimensions are associated with a table in the `Registry` database.  The rows in those tables contain the valid data ID values for that dimension, but they can also contain metadata fields and foreign key fields that are used to model relationships between dimensions.  The rows in the dimension tables are the same across all collections - that's important, because we want the meaning of a data ID to be consistent across (e.g.) different processing runs.  Dimensions form a sort of scaffolding or skeleton for datasets - datasets do not have relationships of their own; instead we rely on the web of dimension relationships to connect them.
#
# The full set of dimensions known to a `Registry` is stored in a class called the `DimensionUniverse`:

# %%
butler.registry.dimensions
# Out:
# DimensionUniverse({htm7, htm9, abstract_filter, instrument, skymap, calibration_label, detector, physical_filter, subfilter, tract, visit_system, exposure, patch, visit})

# %% [markdown]
# You can get dimension instances via dict-like indexing on this object, and we'll use that to take a closer look at the `visit` dimension:

# %%
visit = butler.registry.dimensions["visit"]

# %% [markdown]
# Note that this object represents the _concept_ of a visit, not a particular visit.
#
# Let's start by printing the fields of the visit table:

# %%
lsst.daf.butler.datastores.posixDatastore   # HMK just tossed this in here to try to get it to work
def printFieldSpecs(*specs):
    """Print the names and types from one or more FieldSpec instances."""
    for spec in specs:
        print(f"{spec.name} ({spec.dtype.__name__})")
        
printFieldSpecs(*visit.makeTableSpec().fields)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-343c45eaa688> in <module>
# ----> 1 lsst.daf.butler.datastores.posixDatastore   # HMK just tossed this in here to try to get it to work
#       2 def printFieldSpecs(*specs):
#       3     """Print the names and types from one or more FieldSpec instances."""
#       4     for spec in specs:
#       5         print(f"{spec.name} ({spec.dtype.__name__})")
#
# NameError: name 'lsst' is not defined

# %% [markdown]
# Some of these (`exposure_time`, `seeing`) are just metadata fields with no special structure.  We'll have to add more of these to `visit` in the future - this just isn't something we've tried to be comprehensive about yet.
#
# The `region` and `datetime*` fields are present because `visit` is `spatial` and `temporal`, respectively:

# %%
print(visit.spatial, visit.temporal)
# Out:
# visit_detector_region exposure

# %% [markdown]
# These form implied relationships to any other dimension that is spatial and/or temporal, via the overlap of their regions and/or timespans.

# %% [markdown]
# The `id` field is the _primary key_ for `visit`, which means it's what you use as the value in data ID key-value pairs.  `name` is an _alternate key_, which means it also uniquely identifies a visit, and someday we plan to make those usable as data ID values (but haven't yet):

# %%
printFieldSpecs(visit.primaryKey)
printFieldSpecs(*visit.alternateKeys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-21546d8ad908> in <module>
# ----> 1 printFieldSpecs(visit.primaryKey)
#       2 printFieldSpecs(*visit.alternateKeys)
#
# NameError: name 'printFieldSpecs' is not defined

# %% [markdown]
# The _database_ primary key for the `visit` table isn't just `id`, though - `visit` has a _required dependency_ on the `instrument` dimension, which means it has a foreign key to the `instrument` table that is also part of its (compound) primary key:

# %%
print(visit.graph.required)
# Out:
# {instrument, visit}

# %% [markdown]
# This required dependency means that whenever the `visit` key appears in a data ID, the `instrument` key must as well.  You've already seen another example of this: the `tract` dimension has a required dependency on the `skymap` dimension:

# %%
print(butler.registry.dimensions["tract"].graph.required)
# Out:
# {skymap, tract}

# %% [markdown]
# Finally, `visit` has an _implied dependency_ on the `physical_filter` dimension:

# %%
print(visit.implied)
# Out:
# {physical_filter, visit_system}

# %% [markdown]
# On the database side, that means that the `visit` table has a `physical_filter` field that is a foreign key but _not_ a primary key.  In terms of data IDs, this means that you _don't_ need to pass a `physical_filter` key in a data ID that involves `visit`, but the `Registry` can add one for you based on what's in the database.

# %% [markdown]
# ### ExpandedDataCoordinate
#
# You can get that extra dimension information from the `Registry` by calling `expandDataId`:

# %%
#expanded = butler.registry.expandDataId({"instrument": "HSC", "visit": 903338})
expanded = butler.registry.expandDataId({"instrument": "LSST-ImSim", "visit": 443964})

# %% [markdown]
# When you expand a data ID like this, you get everything the database knows about those dimensions, and it comes in a special subclass of `DataCoordinate`.  In order to make it [strictly substitutable](https://en.wikipedia.org/wiki/Liskov_substitution_principle) for `DataCoordinate`, its behavior can be a little tricky; while you can ask it for the values of implied dimensions:

# %%
expanded["physical_filter"]
# Out:
# 'z'

# %% [markdown]
# they don't appear in `keys()` or iteration, which are still just the required dimensions:

# %%
expanded.keys()
# Out:
# dict_keys([Dimension(instrument), Dimension(visit)])

# %% [markdown]
# You can get a dict with the full set of keys with:

# %%
print(expanded.full)
# Out:
# {abstract_filter: z, instrument: LSST-ImSim, physical_filter: z, visit_system: 0, visit: 443964}

# %% [markdown]
# Note that `abstract_filter` is here, too, not just `physical_filter`.  That's because `physical_filter` has an implied dependency on `abstract_filter`, and those dependencies are expanded recursively:

# %%
print(butler.registry.dimensions["physical_filter"].implied)
# Out:
# {abstract_filter}

# %% [markdown]
# `ExpandedDataCoordinate.records` is a dictionary with all of the metadata of all of the dimensions:

# %%
# While writing this I discovered that some of these classes don't
# have a nice `__str__` or `__repr__` yet, and ought to; here's a
# snippet to do that for now.
for dimension, record in expanded.records.items():
    print(dimension)
    for field, value in record.toDict().items():
        print(f"  {field}: {value}")
# Out:
# abstract_filter
#   name: z
# instrument
#   name: LSST-ImSim
#   visit_max: 9999999999
#   exposure_max: 9999999999
#   detector_max: 999
#   class_name: lsst.obs.lsst.LsstImSim
# physical_filter
#   instrument: LSST-ImSim
#   name: z
#   abstract_filter: z
# visit_system
#   instrument: LSST-ImSim
#   id: 0
#   name: one-to-one
# visit
#   instrument: LSST-ImSim
#   id: 443964
#   physical_filter: z
#   visit_system: 0
#   name: 443964
#   exposure_time: 30.0
#   seeing: None
#   region: ConvexPolygon([UnitVector3d(0.3768244112345154, 0.6127673194333143, -0.6946362899620717), UnitVector3d(0.3753901489117097, 0.615992541908073, -0.6925571632823354), UnitVector3d(0.38154367879668344, 0.6262289283394811, -0.6798983383426366), UnitVector3d(0.38484217703543727, 0.6264078868818407, -0.6778714170304367), UnitVector3d(0.38832371672248395, 0.6265830269457473, -0.6757206533578362), UnitVector3d(0.4091302992395544, 0.6273995180199263, -0.6625573507497421), UnitVector3d(0.41256812509343005, 0.6274948514087825, -0.6603315482485763), UnitVector3d(0.42723339222258555, 0.6180965277048173, -0.6598699197639112), UnitVector3d(0.42862839216167825, 0.6149909964057282, -0.6618638649849259), UnitVector3d(0.43006383361765466, 0.6117550887857098, -0.6639283171840726), UnitVector3d(0.431491158182822, 0.6085109387713126, -0.6659803434078988), UnitVector3d(0.43991019902759315, 0.5887914713062641, -0.6780882096810916), UnitVector3d(0.4337399880012369, 0.5785538987915767, -0.690756837824826), UnitVector3d(0.4304931646072069, 0.5784513063038673, -0.6928706383314434), UnitVector3d(0.4201334621602332, 0.5780837111950801, -0.6995048940673534), UnitVector3d(0.41666803037100475, 0.5779428787968769, -0.701690659275671), UnitVector3d(0.4062123272717275, 0.5774660337962445, -0.7081839626708033), UnitVector3d(0.4027219629003944, 0.5772880836381165, -0.7103192867204751), UnitVector3d(0.38806860293329537, 0.586679571084863, -0.7107811479556007), UnitVector3d(0.3867262074036938, 0.5898628371262075, -0.7088756406342204), UnitVector3d(0.3853303348532911, 0.5931582016834095, -0.7068832158267405)])
#   datetime_begin: 2023-09-29 06:47:13.109
#   datetime_end: 2023-09-29 06:47:43.109

# %% [markdown]
# Finally, you can ask an `ExpandedDataCoordinate` for its `region`, which is a [lsst.sphgeom.ConvexPolygon](http://doxygen.lsst.codes/stack/doxygen/x_masterDoxyDoc/classlsst_1_1sphgeom_1_1_convex_polygon.html) if the data ID corresponds to a region on the sky, or `None` if it does not:

# %%
expanded.region
# Out:
# ConvexPolygon([UnitVector3d(0.3768244112345154, 0.6127673194333143, -0.6946362899620717), UnitVector3d(0.3753901489117097, 0.615992541908073, -0.6925571632823354), UnitVector3d(0.38154367879668344, 0.6262289283394811, -0.6798983383426366), UnitVector3d(0.38484217703543727, 0.6264078868818407, -0.6778714170304367), UnitVector3d(0.38832371672248395, 0.6265830269457473, -0.6757206533578362), UnitVector3d(0.4091302992395544, 0.6273995180199263, -0.6625573507497421), UnitVector3d(0.41256812509343005, 0.6274948514087825, -0.6603315482485763), UnitVector3d(0.42723339222258555, 0.6180965277048173, -0.6598699197639112), UnitVector3d(0.42862839216167825, 0.6149909964057282, -0.6618638649849259), UnitVector3d(0.43006383361765466, 0.6117550887857098, -0.6639283171840726), UnitVector3d(0.431491158182822, 0.6085109387713126, -0.6659803434078988), UnitVector3d(0.43991019902759315, 0.5887914713062641, -0.6780882096810916), UnitVector3d(0.4337399880012369, 0.5785538987915767, -0.690756837824826), UnitVector3d(0.4304931646072069, 0.5784513063038673, -0.6928706383314434), UnitVector3d(0.4201334621602332, 0.5780837111950801, -0.6995048940673534), UnitVector3d(0.41666803037100475, 0.5779428787968769, -0.701690659275671), UnitVector3d(0.4062123272717275, 0.5774660337962445, -0.7081839626708033), UnitVector3d(0.4027219629003944, 0.5772880836381165, -0.7103192867204751), UnitVector3d(0.38806860293329537, 0.586679571084863, -0.7107811479556007), UnitVector3d(0.3867262074036938, 0.5898628371262075, -0.7088756406342204), UnitVector3d(0.3853303348532911, 0.5931582016834095, -0.7068832158267405)])

# %% [markdown]
# As we discussed earlier, this region may be heavily padded to account for inaccurate initial WCSs, but they should be guaranteed contain the true region.

# %% [markdown]
# ### DimensionGraph
#
# The sometimes-complex system of relationships between dimensions makes it very useful to have a specialized container for them, and we've actually already seen this class (`DimensionGraph`) in use in a few places:

# %%
deepCoaddType.dimensions
# Out:
# DimensionGraph({abstract_filter, skymap, tract, patch})

# %%
ref.dataId.graph
# Out:
# DimensionGraph({abstract_filter, skymap, tract, patch})

# %%
visit.graph
# Out:
# DimensionGraph({abstract_filter, instrument, physical_filter, visit_system, visit})

# %% [markdown]
# `DimensionUniverse` is a special subclass of `DimensionGraph` as well.

# %% [markdown]
# To explore `DimensionGraph` further, we'll start by extracting an interesting and common set of dimensions from the universe - these are the ones used to label the `calexp` dataset:

# %%
graph = butler.registry.dimensions.extract(["detector", "visit"])
print(graph)
# Out:
# {abstract_filter, instrument, detector, physical_filter, visit_system, visit}

# %% [markdown]
# The first thing to note here is that the set of dimensions is automatically expanded to include all (recursive) required and implied dimensions.  The dimensions are also sorted topologically (dependents follow their dependencies), with string (lexicographical) comparisons to break ties.
#
# We can ask a `DimensionGraph` for its `required` and `implied` dimensions:

# %%
print(graph.required)
print(graph.implied)
# Out:
# {instrument, detector, visit}
# {abstract_filter, physical_filter, visit_system}

# %% [markdown]
# Note that which dimensions are `implied` depends on which dimensions are present; `physical_filter` is only `implied` here because `visit` is also in the graph.
#
# The *required* dimensions of a graph are particularly important, because those are the keys of a `DataCoordinate` that identifies the dimensions of that graph.
#
# You can also ask a `DimensionGraph` for its `temporal` and `spatial` dimensions:

# %%
print(graph.temporal)
# Out:
# {visit}

# %%
print(graph.spatial)
# Out:
# {visit_detector_region}

# %% [markdown]
# That last answer is a bit unexpected - `visit_detector_region` isn't even one of the dimensions in the graph!  Instead, it's a table that's part of the dimensions system, without being an actual `Dimension` itself.  It can't be used as a data ID key, but it is used to provide other information about true dimensions.  In this case, that extra information is the `region` associated with the _combination_ of a `visit` and a `detector`.  A `visit` has its own region, but the system knows that the one provided by `visit_detector_region` is more specific and hence a better match for this graph.
#
# The graph's spatial dimension is what defines the `region` attribute of any `ExpandedDataCoordinate` for that graph.  That's why we want to select the "best" spatial dimension rather than reporting all of them; if a graph has more than one spatial dimension and neither is clearly better, we don't currently define a region for it (though perhaps we will someday):

# %%
#dataIdWithAmbiguousRegion = butler.registry.expandDataId({"skymap": "discrete/ci_hsc", "tract": 0, "instrument": "HSC", "visit": 903334})  
dataIdWithAmbiguousRegion = butler.registry.expandDataId({"skymap": "imsim_skymap", "tract": 3078, "instrument": "LSST-ImSim", "visit": 443964})

print(dataIdWithAmbiguousRegion.graph.spatial)
# Out:
# {tract, visit}

# %%
dataIdWithAmbiguousRegion.region
# Out:
# NotImplemented

# %% [markdown]
# We _return_ the special `NotImplemented` object instead of raising an exception because we don't want to completely fail to construct an `ExpandedDataCoordinate` just because its region isn't well-defined, and return `None` already expresses the slightly different case where there are no spatial dimensions.

# %% [markdown]
# ### SkyPix Dimensions

# %% [markdown]
# The `htm7` and `htm9` dimensions in this universe are special; they're represented in code by the `SkyPixDimension` subclass:

# %%
htm9 = butler.registry.dimensions["htm9"]
htm9
# Out:
# SkyPixDimension(htm9)

# %% [markdown]
# A skypix dimension represents a particular level of a particular hierarchical pixelization of the sky, which corresponds to an instance of [lsst.sphgeom.Pixelization](http://doxygen.lsst.codes/stack/doxygen/x_masterDoxyDoc/classlsst_1_1sphgeom_1_1_pixelization.html).

# %%
htm9.pixelization
# Out:
# HtmPixelization(9)

# %% [markdown]
# A `Pixelization` instance knows how to go from integer IDs to regions on the sky and back:

# %%
print(htm9.pixelization.envelope(observationDataId.region))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-c69d73d4bea1> in <module>
# ----> 1 print(htm9.pixelization.envelope(observationDataId.region))
#
# NameError: name 'observationDataId' is not defined

# %%
print(htm9.pixelization.pixel(3031552))
# Out:
# ConvexPolygon([UnitVector3d(0.773010453362737, -0.6343932841636455, 0.0), UnitVector3d(0.7710605242618138, -0.6367618612362842, 0.0), UnitVector3d(0.7725653343241956, -0.6349265062178546, -0.003337049974569806)])

# %% [markdown]
# Because these mappings are fully defined in code, we don't also put them in the database, so `skypix` dimensions don't have their own entries in the `Registry` database.
#
# However, we also use *one* skypix dimension, called the "common" skypix dimension, as a sort of spatial index that relates all other spatial dimensions in the database.  It still doesn't have its own table, but the database does have join tables that relate the common skypix dimension's IDs to the primary keys of other dimensions.  Usually this should be completely transparent.  You can get the common skypix dimension from the universe:

# %%
butler.registry.dimensions.commonSkyPix
# Out:
# SkyPixDimension(htm7)

# %% [markdown]
# ### Querying Dimensions

# %% [markdown]
# You can use `Registry.queryDimensions` to run complex queries that return data IDs.  It accepts many of the same arguments as `queryDatasets`, and also returns iterators.  The first set of arguments is the set of dimensions the returned data IDs should include.  This can be any iterable over strings or `Dimension` instances, and will be expanded to a self-consistent `DimensionGraph` automatically:

# %%
for dataId in butler.registry.queryDimensions(["visit"], instrument="LSST-ImSim", physical_filter="z"):
    print(dataId)
# Out:
# {instrument: LSST-ImSim, visit: 32683}
# {instrument: LSST-ImSim, visit: 443964}
# {instrument: LSST-ImSim, visit: 240855}
# {instrument: LSST-ImSim, visit: 426663}
# {instrument: LSST-ImSim, visit: 237907}
# {instrument: LSST-ImSim, visit: 209058}
# {instrument: LSST-ImSim, visit: 209066}
# {instrument: LSST-ImSim, visit: 13289}
# {instrument: LSST-ImSim, visit: 209091}
# {instrument: LSST-ImSim, visit: 303558}

# %% [markdown]
# It's worth noting that you have to include `instrument` here if you want to pass `physical_filter` as a partial data ID (the same would be true in `queryDataset`) because we convert the given data ID into an `ExpandedDataCoordinate` *before* we run the query.  That can't work unless you specify the `instrument`, because the `physical_filter` dimension has a required dependency on the `instrument` dimension:

# %%
for dataId in butler.registry.queryDimensions(["visit"], physical_filter="z"):
    print(dataId)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2020_27/stack/miniconda3-py37_4.8.2-1a1d771/Linux64/daf_butler/19.0.0-113-g0a1db075/python/lsst/daf/butler/core/dimensions/coordinate.py in standardize(mapping, graph, universe, **kwargs)
#     163         try:
# --> 164             values = tuple(d[name] for name in graph.required.names)
#     165             # some backends cannot handle numpy.int64 type which is
#
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2020_27/stack/miniconda3-py37_4.8.2-1a1d771/Linux64/daf_butler/19.0.0-113-g0a1db075/python/lsst/daf/butler/core/dimensions/coordinate.py in <genexpr>(.0)
#     163         try:
# --> 164             values = tuple(d[name] for name in graph.required.names)
#     165             # some backends cannot handle numpy.int64 type which is
#
# KeyError: 'instrument'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-0b52995242cd> in <module>
# ----> 1 for dataId in butler.registry.queryDimensions(["visit"], physical_filter="z"):
#       2     print(dataId)
#
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2020_27/stack/miniconda3-py37_4.8.2-1a1d771/Linux64/daf_butler/19.0.0-113-g0a1db075/python/lsst/daf/butler/registry/_registry.py in queryDimensions(self, dimensions, dataId, datasets, collections, where, expand, components, **kwargs)
#    1100         """
#    1101         dimensions = iterable(dimensions)
# -> 1102         standardizedDataId = self.expandDataId(dataId, **kwargs)
#    1103         standardizedDatasetTypes = set()
#    1104         requestedDimensionNames = set(self.dimensions.extract(dimensions).names)
#
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2020_27/stack/miniconda3-py37_4.8.2-1a1d771/Linux64/daf_butler/19.0.0-113-g0a1db075/python/lsst/daf/butler/registry/_registry.py in expandDataId(self, dataId, graph, records, **kwargs)
#     792             identifieds.
#     793         """
# --> 794         standardized = DataCoordinate.standardize(dataId, graph=graph, universe=self.dimensions, **kwargs)
#     795         if isinstance(standardized, ExpandedDataCoordinate):
#     796             return standardized
#
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2020_27/stack/miniconda3-py37_4.8.2-1a1d771/Linux64/daf_butler/19.0.0-113-g0a1db075/python/lsst/daf/butler/core/dimensions/coordinate.py in standardize(mapping, graph, universe, **kwargs)
#     167             values = tuple(int(val) if isinstance(val, numbers.Integral) else val for val in values)
#     168         except KeyError as err:
# --> 169             raise KeyError(f"No value in data ID ({mapping}) for required dimension {err}.") from err
#     170         return DataCoordinate(graph, values)
#     171
#
# KeyError: "No value in data ID (None) for required dimension 'instrument'."

# %% [markdown]
# You _can_ query on just `physical_filter` using a string expression...

# %%
for dataId in butler.registry.queryDimensions(["visit"], where="physical_filter = 'z'"):
    print(dataId)
# Out:
# {instrument: LSST-ImSim, visit: 303558}
# {instrument: LSST-ImSim, visit: 209091}
# {instrument: LSST-ImSim, visit: 13289}
# {instrument: LSST-ImSim, visit: 209066}
# {instrument: LSST-ImSim, visit: 209058}
# {instrument: LSST-ImSim, visit: 237907}
# {instrument: LSST-ImSim, visit: 426663}
# {instrument: LSST-ImSim, visit: 240855}
# {instrument: LSST-ImSim, visit: 443964}
# {instrument: LSST-ImSim, visit: 32683}

# %% [markdown]
# ...but this may not be what you want.  In a larger, more realistic repository, this will actually search over all instruments, and while our _convention_ of putting the instrument name in the physical filter string would still save us from getting results from those other instruments here, it might be less efficient, and variations on this case involving other dimensions might produce undesired results.  From that perspective, the requirement that any data ID passed be complete and self-consistent is a feature, not a bug, and we relax it in the string-based query system because it's intended to be much more flexible (and hence can't be as careful).

# %% [markdown]
# Like `queryDatasets`, `queryDimensions` will automatically use spatial or temporal relationships, as well as implied dimension relationships:

# %%
for dataId in butler.registry.queryDimensions(["visit"], dataId={"skymap": "imsim_skymap", "tract": 3078, "patch": 26, "abstract_filter": "z"}):
    print(dataId)
# Out:
# {instrument: LSST-ImSim, visit: 32683}
# {instrument: LSST-ImSim, visit: 32683}
# {instrument: LSST-ImSim, visit: 32683}
# {instrument: LSST-ImSim, visit: 32683}
# {instrument: LSST-ImSim, visit: 32683}
# {instrument: LSST-ImSim, visit: 32683}
# {instrument: LSST-ImSim, visit: 443964}
# {instrument: LSST-ImSim, visit: 443964}
# {instrument: LSST-ImSim, visit: 443964}
# {instrument: LSST-ImSim, visit: 443964}
# {instrument: LSST-ImSim, visit: 443964}
# {instrument: LSST-ImSim, visit: 443964}
# {instrument: LSST-ImSim, visit: 240855}
# {instrument: LSST-ImSim, visit: 240855}
# {instrument: LSST-ImSim, visit: 240855}
# {instrument: LSST-ImSim, visit: 240855}
# {instrument: LSST-ImSim, visit: 240855}
# {instrument: LSST-ImSim, visit: 240855}
# {instrument: LSST-ImSim, visit: 426663}
# {instrument: LSST-ImSim, visit: 426663}
# {instrument: LSST-ImSim, visit: 426663}
# {instrument: LSST-ImSim, visit: 426663}
# {instrument: LSST-ImSim, visit: 426663}
# {instrument: LSST-ImSim, visit: 426663}
# {instrument: LSST-ImSim, visit: 237907}
# {instrument: LSST-ImSim, visit: 237907}
# {instrument: LSST-ImSim, visit: 237907}
# {instrument: LSST-ImSim, visit: 237907}
# {instrument: LSST-ImSim, visit: 237907}
# {instrument: LSST-ImSim, visit: 237907}
# {instrument: LSST-ImSim, visit: 209058}
# {instrument: LSST-ImSim, visit: 209058}
# {instrument: LSST-ImSim, visit: 209058}
# {instrument: LSST-ImSim, visit: 209058}
# {instrument: LSST-ImSim, visit: 209058}
# {instrument: LSST-ImSim, visit: 209058}
# {instrument: LSST-ImSim, visit: 209066}
# {instrument: LSST-ImSim, visit: 209066}
# {instrument: LSST-ImSim, visit: 209066}
# {instrument: LSST-ImSim, visit: 209066}
# {instrument: LSST-ImSim, visit: 209066}
# {instrument: LSST-ImSim, visit: 209066}
# {instrument: LSST-ImSim, visit: 13289}
# {instrument: LSST-ImSim, visit: 13289}
# {instrument: LSST-ImSim, visit: 13289}
# {instrument: LSST-ImSim, visit: 13289}
# {instrument: LSST-ImSim, visit: 13289}
# {instrument: LSST-ImSim, visit: 13289}
# {instrument: LSST-ImSim, visit: 209091}
# {instrument: LSST-ImSim, visit: 209091}
# {instrument: LSST-ImSim, visit: 209091}
# {instrument: LSST-ImSim, visit: 209091}
# {instrument: LSST-ImSim, visit: 209091}
# {instrument: LSST-ImSim, visit: 209091}
# {instrument: LSST-ImSim, visit: 303558}
# {instrument: LSST-ImSim, visit: 303558}
# {instrument: LSST-ImSim, visit: 303558}
# {instrument: LSST-ImSim, visit: 303558}
# {instrument: LSST-ImSim, visit: 303558}
# {instrument: LSST-ImSim, visit: 303558}

# %% [markdown]
# And while data IDs are not dependent on any dataset type or collection, you can query for the data IDs for which some set of datasets (all) exist in one or more collections.  For example, this query returns all detectors for which a `flat` dataset exists in the `calib/hsc` collection:

# %%
for dataId in butler.registry.queryDimensions(["detector"], datasets={"flat": ["LSST-ImSim/calib"]}):
    print(dataId)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-8b9a2d88be7a> in <module>
# ----> 1 for dataId in butler.registry.queryDimensions(["detector"], datasets={"flat": ["LSST-ImSim/calib"]}):
#       2     print(dataId)
#
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2020_27/stack/miniconda3-py37_4.8.2-1a1d771/Linux64/daf_butler/19.0.0-113-g0a1db075/python/lsst/daf/butler/registry/_registry.py in queryDimensions(self, dimensions, dataId, datasets, collections, where, expand, components, **kwargs)
#    1105         if datasets is not None:
#    1106             if collections is None:
# -> 1107                 raise TypeError("Cannot pass 'datasets' without 'collections'.")
#    1108             for datasetType in self.queryDatasetTypes(datasets, components=components):
#    1109                 requestedDimensionNames.update(datasetType.dimensions.names)
#
# TypeError: Cannot pass 'datasets' without 'collections'.

# %% [markdown]
# Well.  That worked, but it actually gave us much more than we asked for, which was data IDs with just `detector` (and `instrument`, since that's a required dependency).  This is a bug, and I've just made a ticket ([DM-22176](https://jira.lsstcorp.org/browse/DM-22176)) for it.
#
# Not a bad thing to close on a pretty representative example of the fact that this is all still under construction, even if it can already do a lot.

# %% [markdown]
# ## Appendix: what about `put`?
#
# It's just like `get`, but you pass the thing you want to write as the first argument, and you can't use `parameters`.  You can use `DatasetRef`.  There is no return value.  You can find more documentation [here](https://pipelines.lsst.io/py-api/lsst.daf.butler.Butler.html#lsst.daf.butler.Butler.put).
#
# That won't work here (by design; there's a good chance you're using a shared example repo we don't want to break), because the `Butler` we constructed is read-only.  If you want a read-write `Butler`, construct the `Butler` with a `run` argument instead of a `collection` argument.  The value for that is the name of a special kind of collection that we call a `Run`.  The `shared/ci_hsc_output` collection we've been using is actually the name of a `Run`, but passing it as a regular collection tells the `Butler` that we don't plan to write anything to it.
